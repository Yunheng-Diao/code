# %%
import abagen

# 下载 Allen 数据到默认目录 ~/.abagen-data/allenhuman
abagen.datasets.fetch_microarray(donors='all')  # 下载全部6位捐赠者数据

# %%
expression = abagen.get_expression_data(
    atlas=r"E:\aliyun_backup\muilt_disorders\01_altas\BNA246_Cerebellum_Stem_altas_Asym.nii",
    missing='centroids',
    data_dir="C:\\Users\\diaoy\\abagen-data\\microarray",
    verbose=True                        # 显示下载和处理信息
)

# %%
expression.to_csv(r'E:\aliyun_backup\muilt_disorders\13_Allen\AHBA_expression.csv')
